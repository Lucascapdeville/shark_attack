# %% [markdown]
# # Data cleanning dos dados referentes a casos de ataques de tubarão.
#
# Primeira pergunta - Spray anti tubarão aonde vender?

# %%
import pandas as pd
import numpy as np
import re

# %%
shark =  pd.read_csv('data/attacks.csv', sep = ',', encoding = 'windows-1252' )
shark.head(10)
# Out:
#     Case Number         Date    Year        Type    Country             Area  \
# 0    2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1    2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2    2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3    2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4    2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# 5  2018.06.03.b  03-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 6  2018.06.03.a  03-Jun-2018  2018.0  Unprovoked     BRAZIL       Pernambuco
# 7    2018.05.27  27-May-2018  2018.0  Unprovoked        USA          Florida
# 8  2018.05.26.b  26-May-2018  2018.0  Unprovoked        USA          Florida
# 9  2018.05.26.a  26-May-2018  2018.0  Unprovoked        USA          Florida
#
#                                             Location      Activity  \
# ...

# %%
shark.info
# Out:
# <bound method DataFrame.info of       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# ...

# %% [markdown]
# ## Primeiras observações de arquivos:Nome das colunas, limpar valores nones , checar duplicadas.
# colunas Unnamed? nan information? pdf??

# %% [markdown]
# ### Arrumando as colunas e removendo as colunas vazias

# %%
shark.columns
shark.columns = [col.lower().replace(' ','_').replace('/','_') for col in shark.columns]
shark.drop(['unnamed:_22','unnamed:_23'], axis = 1,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [84], in <cell line: 3>()
#       1 shark.columns
#       2 shark.columns = [col.lower().replace(' ','_').replace('/','_') for col in shark.columns]
# ----> 3 shark.drop(['unnamed:_22','unnamed:_23'], axis = 1,inplace = True)
#       4 shark.head(10)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
shark.head()
# Out:
#   case_number         date    year        type    country             area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          location     activity             name sex_  ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %% [markdown]
# ### Removendo as duplicadas e valores nulos

# %%
shark = shark[~shark['case_number'].isna()]
shark = shark[shark['case_number'] != '0']
shark.head(10)
# Out:
#     case_number         date    year        type    country             area  \
# 0    2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1    2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2    2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3    2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4    2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# 5  2018.06.03.b  03-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 6  2018.06.03.a  03-Jun-2018  2018.0  Unprovoked     BRAZIL       Pernambuco
# 7    2018.05.27  27-May-2018  2018.0  Unprovoked        USA          Florida
# 8  2018.05.26.b  26-May-2018  2018.0  Unprovoked        USA          Florida
# 9  2018.05.26.a  26-May-2018  2018.0  Unprovoked        USA          Florida
#
#                                             location      activity  \
# ...

# %% [markdown]
# # Escolhendo as categorias para analise
# colunas: case_number;country;area

# %%
shark.columns
# Out:
# Index(['case_number', 'date', 'year', 'type', 'country', 'area', 'location',
#        'activity', 'name', 'sex_', 'age', 'injury', 'fatal_(y_n)', 'time',
#        'species_', 'investigator_or_source', 'pdf', 'href_formula', 'href',
#        'case_number.1', 'case_number.2', 'original_order'],
#       dtype='object')

# %%
shark_country = shark.loc[:,['case_number','year','country', 'area']]
shark_country = shark_country[~shark_country['country'].isna()]
shark_country['country'].value_counts()
# Out:
# USA                       2228
# AUSTRALIA                 1338
# SOUTH AFRICA               579
# PAPUA NEW GUINEA           134
# NEW ZEALAND                128
#                           ...
# MALDIVE ISLANDS              1
# NICARAGUA                    1
# NORTH SEA                    1
# RED SEA / INDIAN OCEAN       1
# CEYLON (SRI LANKA)           1
# Name: country, Length: 212, dtype: int64

# %% [markdown]
# ## USA e Australia são as melhores areas para iniciar a venda do spray de tubarão
# ### Aonde desses paises ??

# %%
shark_area = shark_country[(shark_country['country'] == 'USA')|(shark_country['country'] == 'AUSTRALIA')]
shark_area['area'].value_counts().head(6)
# Out:
# Florida              1036
# New South Wales       486
# Queensland            311
# Hawaii                298
# California            290
# Western Australia     189
# Name: area, dtype: int64

# %% [markdown]
# Florida, Hawai e Western Australia nos USA
# New south wales, Queensland e Western Australia
